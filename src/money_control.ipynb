# %%
import requests

# %%
url = ('https://newsapi.org/v2/everything?'
       'q=Apple&'
       'from=2024-01-10&'
       'sortBy=popularity&'
       'apiKey=4a345ad30ea64e4eaf521a2721e2037d')

# %%
response = requests.get(url)

# %%
response.text.split("/n")
# Out:
# ['{"status":"ok","totalResults":31900,"articles":[{"source":{"id":null,"name":"Yahoo Entertainment"},"author":"Sarah Fielding","title":"Apple ends Samsung\'s decade-plus as global smartphone shipment leader","description":"The year 2023 turned out to be a big one for Apple\'s iPhone. First, it got rid of the longstanding lightning port, and now reports indicate that Apple overtook Samsung for the title of most smartphones shipped globally. The International Data Corporation (IDC…","url":"https://consent.yahoo.com/v2/collectConsent?sessionId=1_cc-session_eca0e63c-39d3-4603-bb52-116e6da31399","urlToImage":null,"publishedAt":"2024-01-16T12:14:13Z","content":"Si vous cliquez sur «\xa0Tout accepter\xa0», nos partenaires (y compris 244 qui font partie du Cadre de transparence et de consentement dIAB) et nous utiliserons également des témoins et vos données person… [+982 chars]"},{"source":{"id":null,"name":"Yahoo Entertainment"},"author":"Sarah Fielding","title":"Apple Podcasts will automa
# ...
